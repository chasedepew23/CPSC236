# %%
import types
conversions = types.ModuleType('conversions')
sys.modules['conversions'] = conversions

def feet_to_meters(feet):
    return feet * 0.3048


def meters_to_feet(meters):
    return meters / 0.3048

conversions.feet_to_meters = feet_to_meters
conversions.meters_to_feet = meters_to_feet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5 def meters_to_feet(meters):
#       6     return meters / 0.3048
# ----> 8 conversions.feet_to_meters = feet_to_meters
#       9 conversions.meters_to_feet = meters_to_feet
#
# NameError: name 'conversions' is not defined
